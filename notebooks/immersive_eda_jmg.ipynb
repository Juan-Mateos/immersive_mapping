# %% [markdown]
# # Immersive exploratory analysis
#
# **Activities**
#
# * Load and process the GlassAI data
# * Load and process Immersive Survey data (including the data processed by Kostas)
# * Match?
# * Produce descriptives and basic visualisations

# %% [markdown]
# ## Preliminaries
#
# Such as paths

# %%
# %matplotlib inline
#NB I install a standard set of directories

#Get the top path
top_path = os.path.dirname(os.getcwd())

#Create the path for external data
ext_data = os.path.join(top_path,'data/external')

fig_path = os.path.join(top_path,'reports/figures')

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Metadata

# %%
#Load nspl to get TTWAs
nspl = pd.read_csv(ext_data+'/NSPL_AUG_2017_UK.csv')

#And TTWA names - codes lookup
ttwa_names = pd.read_table(ext_data+'/ttwa_names_codes.txt',delimiter='\t')

ttwa_codes_names_lookup = {x:y for x,y in zip(ttwa_names['TTWA11CD'],
                                             ttwa_names['TTWA11NM'])}
# Out:
# /usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (30,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# IDBR totals for normalising
idbr = pd.read_csv(ext_data+'/idbr_business_totals.csv')

# %% [markdown]
# ### GlassAI data

# %%
#Load
glass_ai = pd.read_excel(ext_data+'/17_11_2017_company_list_glassai.xlsx')
glass_ai.head()

glass_ai.shape

#Postcodes
glass_postcodes = pd.read_table(ext_data+'/immerse_v4_postcodes.txt',delimiter='\t',header=None)
glass_postcodes.columns=['id','postcode']

glass_ai_geo = pd.merge(glass_ai,glass_postcodes,left_on='Organization ID',right_on='id')
glass_ai_geo['postcode_top'] = [x.split(",")[0].upper() if type(x)==str else np.nan for x in glass_ai_geo.postcode]

glass_ai_geo = pd.merge(glass_ai_geo,nspl[['pcds','ttwa','lat','long']],left_on='postcode_top',right_on='pcds',how='left')
glass_ai_geo['ttwa_name'] = [ttwa_codes_names_lookup[x] if x in ttwa_codes_names_lookup.keys() else np.nan for x in glass_ai_geo['ttwa']]

# %% [markdown]
# ### MTM survey

# %%
#Load data from SPSS
mtm_from_spss = pd.read_csv(ext_data+'/14_01_2018_immersive_survey.csv',encoding='latin1').iloc[:,1:]

#We still need to add the question names and responses. Need to find them.
#For some reason a couple of the columns are missing from the spss file. Load the csv file and merge

mtm_from_csv = pd.read_excel(ext_data+'/14_01_2018_immersive_survey_raw_csv.xls')

#These are the geocodes
mtm_geo_coded = pd.read_csv(ext_data+'/12_01_2018_company_list_geo_located.csv')

#Company House matches - ask Kostas to take me through this.
mtm_ch = pd.read_csv(ext_data+'/12_01_2018_company_list_ch_matches.csv')

#Data dictionary
data_dict = pd.read_excel(ext_data+'/14_01_2018_survey_data_dictionary.xlsx')

mtm_from_spss.columns=data_dict.q_name_short

# %%
#Combine everything and rename
mtm_all = pd.concat([mtm_from_csv.loc[:,['QQ2_1','QQ2_3']],mtm_from_spss,mtm_geo_coded,mtm_ch],axis=1)

mtm_all.rename(columns={'QQ2_1':'name','QQ2_3':'survey_postcode'},inplace=True)

# %%
#Uppercase 
mtm_all['survey_postcode'] = [str(x).upper() for x in mtm_all['survey_postcode']]

mtm_all = pd.merge(mtm_all,nspl[['pcds','ttwa']],left_on='survey_postcode',right_on='pcds',how='left')
mtm_all['ttwa_name']= [ttwa_codes_names_lookup[x] if x in ttwa_codes_names_lookup.keys() else np.nan for x in mtm_all['ttwa']]

# %%
#Now that's the survey data

# %% [markdown]
# **Next steps**
#
# * GlassAI
#   * Ask them for postcodes
#
# * Basic descriptives:
#   * Company roles
#   * Performance
#     * Value
#     * Spend / future spend
#     * Growth
#     * Clients
#   * Favourable factors and barriers in different locations
#   * Ask MTM how can we match GlassAI with the survey responses

# %%
survey_data = mtm_all.copy()

# %%
descriptives = [survey_data.loc[:,x].describe() for x in survey_data.columns]

for x,y in zip(survey_data.columns,descriptives):
    print(x)
    print('======')
    print(y)
    print('\n')
# Out:
# name
# ======
#                   name                                               name
# count              260                                                260
# unique             259                                                  1
# top     The Old Market  I am the best person to complete this question...
# freq                 2                                                260
#
#
# survey_postcode
# ======
# count         260
# unique        254
# top       BN1 4GH
# freq            4
# Name: survey_postcode, dtype: object
#
#
# id
# ======
# count    2.600000e+02
# mean     3.383727e+06
# std      2.195833e+04
# min      3.347648e+06
# 25%      3.372702e+06
# 50%      3.386778e+06
# 75%      3.402251e+06
# max      3.464635e+06
# Name: id, dtype: float64
#
#
# name
# ======
#                   name                                               name
# count              260                                                260
# unique             259                                                  1
# top     The Old Market  I am the best person to complete this question...
# freq                 2                                                260
#
#
# q3_market_role_vr_techdev
# ======
# count     260
# unique      2
# top       Yes
# freq      151
# Name: q3_market_role_vr_techdev, dtype: object
#
#
# q3_market_role_ar_techdev
# ======
# count     260
# unique      2
# top       Yes
# freq      141
# Name: q3_market_role_ar_techdev, dtype: object
#
#
# q3_market_role_other_ie_techdev
# ======
# count     260
# unique      2
# top        No
# freq      150
# Name: q3_market_role_other_ie_techdev, dtype: object
#
#
# q3_market_role_vr_content
# ======
# count     260
# unique      2
# top       Yes
# freq      179
# Name: q3_market_role_vr_content, dtype: object
#
#
# q3_market_role_ar_content
# ======
# count     260
# unique      2
# top       Yes
# freq      153
# Name: q3_market_role_ar_content, dtype: object
#
#
# q3_market_role_other_ie_content
# ======
# count     260
# unique      2
# top        No
# freq      169
# Name: q3_market_role_other_ie_content, dtype: object
#
#
# q3_market_role_vr_distributor
# ======
# count     260
# unique      2
# top        No
# freq      228
# Name: q3_market_role_vr_distributor, dtype: object
#
#
# q3_market_role_ar_distributor
# ======
# count     260
# unique      2
# top        No
# freq      237
# Name: q3_market_role_ar_distributor, dtype: object
#
#
# q3_market_role_other_ie_distributor
# ======
# count     260
# unique      2
# top        No
# freq      243
# Name: q3_market_role_other_ie_distributor, dtype: object
#
#
# q3_market_role_vr_services
# ======
# count     260
# unique      2
# top        No
# freq      157
# Name: q3_market_role_vr_services, dtype: object
#
#
# q3_market_role_ar_services
# ======
# count     260
# unique      2
# top        No
# freq      176
# Name: q3_market_role_ar_services, dtype: object
#
#
# q3_market_role_other_ie_services
# ======
# count     260
# unique      2
# top        No
# freq      196
# Name: q3_market_role_other_ie_services, dtype: object
#
#
# q3_market_role_vr_user
# ======
# count     260
# unique      2
# top       Yes
# freq      137
# Name: q3_market_role_vr_user, dtype: object
#
#
# q3_market_role_ar_user
# ======
# count     260
# unique      2
# top        No
# freq      145
# Name: q3_market_role_ar_user, dtype: object
#
#
# q3_market_role_other_ie_user
# ======
# count     260
# unique      2
# top        No
# freq      169
# Name: q3_market_role_other_ie_user, dtype: object
#
#
# q3_market_role_vr_buyer
# ======
# count     260
# unique      2
# top        No
# freq      161
# Name: q3_market_role_vr_buyer, dtype: object
#
#
# q3_market_role_ar_buyer
# ======
# count     260
# unique      2
# top        No
# freq      178
# Name: q3_market_role_ar_buyer, dtype: object
#
#
# q3_market_role_other_ie_buyer
# ======
# count     260
# unique      2
# top        No
# freq      194
# Name: q3_market_role_other_ie_buyer, dtype: object
#
#
# q3_market_role_vr_network
# ======
# count     260
# unique      2
# top        No
# freq      241
# Name: q3_market_role_vr_network, dtype: object
#
#
# q3_market_role_ar_network
# ======
# count     260
# unique      2
# top        No
# freq      243
# Name: q3_market_role_ar_network, dtype: object
#
#
# q3_market_role_other_ie_network
# ======
# count     260
# unique      2
# top        No
# freq      245
# Name: q3_market_role_other_ie_network, dtype: object
#
#
# q3_market_role_vr_finance
# ======
# count     260
# unique      2
# top        No
# freq      246
# Name: q3_market_role_vr_finance, dtype: object
#
#
# q3_market_role_ar_finance
# ======
# count     260
# unique      2
# top        No
# freq      247
# Name: q3_market_role_ar_finance, dtype: object
#
#
# q3_market_role_other_ie_finance
# ======
# count     260
# unique      2
# top        No
# freq      249
# Name: q3_market_role_other_ie_finance, dtype: object
#
#
# q3_market_role_vr_other
# ======
# count     260
# unique      2
# top        No
# freq      229
# Name: q3_market_role_vr_other, dtype: object
#
#
# q3_market_role_ar_other
# ======
# count     260
# unique      2
# top        No
# freq      235
# Name: q3_market_role_ar_other, dtype: object
#
#
# q3_market_role_other_ie_other
# ======
# count     260
# unique      2
# top        No
# freq      233
# Name: q3_market_role_other_ie_other, dtype: object
#
#
# q3_market_role_vr_none
# ======
# count     260
# unique      2
# top        No
# freq      247
# Name: q3_market_role_vr_none, dtype: object
#
#
# q3_market_role_ar_none
# ======
# count     260
# unique      2
# top        No
# freq      232
# Name: q3_market_role_ar_none, dtype: object
#
#
# q3_market_role_other_ie_none
# ======
# count     260
# unique      2
# top        No
# freq      194
# Name: q3_market_role_other_ie_none, dtype: object
#
#
# q4_product_hardware
# ======
# count     240
# unique      2
# top        No
# freq      205
# Name: q4_product_hardware, dtype: object
#
#
# q4_product_software
# ======
# count     240
# unique      2
# top        No
# freq      157
# Name: q4_product_software, dtype: object
#
#
# q4_product_application
# ======
# count     240
# unique      2
# top        No
# freq      127
# Name: q4_product_application, dtype: object
#
#
# q4_product_content
# ======
# count                                                   240
# unique                                                    2
# top       Content (cinematic, live experiences, marketin...
# freq                                                    143
# Name: q4_product_content, dtype: object
#
#
# q4_product_service
# ======
# count     240
# unique      2
# top        No
# freq      127
# Name: q4_product_service, dtype: object
#
#
# q4_product_other
# ======
# count     240
# unique      2
# top        No
# freq      225
# Name: q4_product_other, dtype: object
#
#
# q5_immersive_use
# ======
# count                         151
# unique                          5
# top       In a some areas we work
# freq                           51
# Name: q5_immersive_use, dtype: object
#
#
# q7_value_new_products
# ======
# count                                                   260
# unique                                                    2
# top       Help us to offer new/improved products and ser...
# freq                                                    170
# Name: q7_value_new_products, dtype: object
#
#
# q7_value_new_markets
# ======
# count     260
# unique      2
# top        No
# freq      206
# Name: q7_value_new_markets, dtype: object
#
#
# q7_value_new_collaborators
# ======
# count     260
# unique      2
# top        No
# freq      229
# Name: q7_value_new_collaborators, dtype: object
#
#
# q7_value_wider_clients
# ======
# count     260
# unique      2
# top        No
# freq      229
# Name: q7_value_wider_clients, dtype: object
#
#
# q7_value_better_perception
# ======
# count     260
# unique      2
# top        No
# freq      131
# Name: q7_value_better_perception, dtype: object
#
#
# q7_value_new_marketing
# ======
# count                                               260
# unique                                                2
# top       Opens up new markets and sectors to work with
# freq                                                163
# Name: q7_value_new_marketing, dtype: object
#
#
# q7_value_fast_prototyping
# ======
# count     260
# unique      2
# top        No
# freq      145
# Name: q7_value_fast_prototyping, dtype: object
#
#
# q7_value_change_culture
# ======
# count     260
# unique      2
# top        No
# freq      211
# Name: q7_value_change_culture, dtype: object
#
#
# q7_value_better_efficiency
# ======
# count     260
# unique      2
# top        No
# freq      164
# Name: q7_value_better_efficiency, dtype: object
#
#
# q7_value_better_organisation
# ======
# count     260
# unique      2
# top        No
# freq      180
# Name: q7_value_better_organisation, dtype: object
#
#
# q7_value_other
# ======
# count     260
# unique      2
# top        No
# freq      229
# Name: q7_value_other, dtype: object
#
#
# q8_immersive_export
# ======
# count     248
# unique      2
# top       Yes
# freq      144
# Name: q8_immersive_export, dtype: object
#
#
# q9_export_market
# ======
# count     146
# unique      8
# top       USA
# freq       45
# Name: q9_export_market, dtype: object
#
#
# q10_local_factors_ecosystem
# ======
# count                 256
# unique                  3
# top       Quite important
# freq                  118
# Name: q10_local_factors_ecosystem, dtype: object
#
#
# q10_local_factors_skills_supply
# ======
# count                256
# unique                 3
# top       Very important
# freq                 125
# Name: q10_local_factors_skills_supply, dtype: object
#
#
# q10_local_factors_good_place
# ======
# count                 256
# unique                  3
# top       Quite important
# freq                  120
# Name: q10_local_factors_good_place, dtype: object
#
#
# q10_local_factors_research_base
# ======
# count                256
# unique                 3
# top       Very important
# freq                 111
# Name: q10_local_factors_research_base, dtype: object
#
#
# q10_local_factors_public_finance
# ======
# count                256
# unique                 3
# top       Very important
# freq                 115
# Name: q10_local_factors_public_finance, dtype: object
#
#
# q10_local_factors_private_finance
# ======
# count                 256
# unique                  3
# top       Quite important
# freq                  112
# Name: q10_local_factors_private_finance, dtype: object
#
#
# q10_local_factors_local_customers
# ======
# count                 256
# unique                  3
# top       Quite important
# freq                  118
# Name: q10_local_factors_local_customers, dtype: object
#
#
# q10_local_factors_infrastructure
# ======
# count                256
# unique                 3
# top       Very important
# freq                 193
# Name: q10_local_factors_infrastructure, dtype: object
#
#
# q10_local_factors_technology_expertise
# ======
# count                256
# unique                 3
# top       Very important
# freq                 177
# Name: q10_local_factors_technology_expertise, dtype: object
#
#
# q12_finance_friends_family
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              192
# Name: q12_finance_friends_family, dtype: object
#
#
# q12_finance_crowdfunding
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              236
# Name: q12_finance_crowdfunding, dtype: object
#
#
# q12_finance_equity
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              189
# Name: q12_finance_equity, dtype: object
#
#
# q12_finance_banks
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              219
# Name: q12_finance_banks, dtype: object
#
#
# q12_finance_incubator_accelerator
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              198
# Name: q12_finance_incubator_accelerator, dtype: object
#
#
# q12_finance_coworking_space
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              189
# Name: q12_finance_coworking_space, dtype: object
#
#
# q12_finance_local_grant
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              170
# Name: q12_finance_local_grant, dtype: object
#
#
# q12_finance_national_grant
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              126
# Name: q12_finance_national_grant, dtype: object
#
#
# q12_finance_tax_incentives
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              145
# Name: q12_finance_tax_incentives, dtype: object
#
#
# q13_other_support_mentoring
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              136
# Name: q13_other_support_mentoring, dtype: object
#
#
# q13_other_support_training_tech
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              156
# Name: q13_other_support_training_tech, dtype: object
#
#
# q13_other_support_training_marketing
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              156
# Name: q13_other_support_training_marketing, dtype: object
#
#
# q13_other_support_placements
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              179
# Name: q13_other_support_placements, dtype: object
#
#
# q13_other_support_university_support
# ======
# count                             256
# unique                              3
# top       Neither sought nor received
# freq                              133
# Name: q13_other_support_university_support, dtype: object
#
#
# q14_barriers_finance
# ======
# count     256
# unique      2
# top        No
# freq      153
# Name: q14_barriers_finance, dtype: object
#
#
# q14_barriers_economic_climate
# ======
# count     256
# unique      2
# top        No
# freq      202
# Name: q14_barriers_economic_climate, dtype: object
#
#
# q14_barriers_skills_shortages
# ======
# count     256
# unique      2
# top        No
# freq      135
# Name: q14_barriers_skills_shortages, dtype: object
#
#
# q14_barriers_skills_shortages_education
# ======
# count     256
# unique      2
# top        No
# freq      152
# Name: q14_barriers_skills_shortages_education, dtype: object
#
#
# q14_barriers_access_university_knowledge
# ======
# count     256
# unique      2
# top        No
# freq      214
# Name: q14_barriers_access_university_knowledge, dtype: object
#
#
# q14_barriers_technical_infrastructure
# ======
# count     256
# unique      2
# top        No
# freq      222
# Name: q14_barriers_technical_infrastructure, dtype: object
#
#
# q14_barriers_market_knowledge
# ======
# count     256
# unique      2
# top        No
# freq      210
# Name: q14_barriers_market_knowledge, dtype: object
#
#
# q14_barriers_lack_advice
# ======
# count     256
# unique      2
# top        No
# freq      210
# Name: q14_barriers_lack_advice, dtype: object
#
#
# q14_barriers_office_space
# ======
# count     256
# unique      2
# top        No
# freq      208
# Name: q14_barriers_office_space, dtype: object
#
#
# q14_barriers_government_policy
# ======
# count     256
# unique      2
# top        No
# freq      214
# Name: q14_barriers_government_policy, dtype: object
#
#
# q14_barriers_transport
# ======
# count     256
# unique      2
# top        No
# freq      172
# Name: q14_barriers_transport, dtype: object
#
#
# q14_barriers_technology_understanding
# ======
# count     256
# unique      2
# top        No
# freq      164
# Name: q14_barriers_technology_understanding, dtype: object
#
#
# q14_barriers_device_penetratiom
# ======
# count     256
# unique      2
# top        No
# freq      137
# Name: q14_barriers_device_penetratiom, dtype: object
#
#
# q14_barriers_business_model
# ======
# count     256
# unique      2
# top        No
# freq      160
# Name: q14_barriers_business_model, dtype: object
#
#
# q14_barriers_lack_standards
# ======
# count     256
# unique      2
# top        No
# freq      189
# Name: q14_barriers_lack_standards, dtype: object
#
#
# q14_barriers_fragmented_tech_ecosystem
# ======
# count     256
# unique      2
# top        No
# freq      152
# Name: q14_barriers_fragmented_tech_ecosystem, dtype: object
#
#
# q14_barriers_poor_applications
# ======
# count     256
# unique      2
# top        No
# freq      189
# Name: q14_barriers_poor_applications, dtype: object
#
#
# q14_barriers_lack_time_resources
# ======
# count                                                   256
# unique                                                    2
# top       Lack of understanding of the potential of imme...
# freq                                                    135
# Name: q14_barriers_lack_time_resources, dtype: object
#
#
# q14_barriers_oher
# ======
# count     256
# unique      2
# top        No
# freq      236
# Name: q14_barriers_oher, dtype: object
#
#
# q15_company_incorporation
# ======
# count     260.000000
# mean     2003.273077
# std        23.841142
# min      1900.000000
# 25%      2002.000000
# 50%      2012.000000
# 75%      2016.000000
# max      2017.000000
# Name: q15_company_incorporation, dtype: float64
#
#
# q16_employees
# ======
# count     260
# unique      9
# top       1-2
# freq       76
# Name: q16_employees, dtype: object
#
#
# q17_freelancers
# ======
# count     260
# unique      7
# top       3-5
# freq       60
# Name: q17_freelancers, dtype: object
#
#
# q18_clients_media
# ======
# count     260
# unique      2
# top        No
# freq      150
# Name: q18_clients_media, dtype: object
#
#
# q18_clients_education
# ======
# count     260
# unique      2
# top        No
# freq      185
# Name: q18_clients_education, dtype: object
#
#
# q18_clients_software_development
# ======
# count                         260
# unique                          2
# top       Media and entertainment
# freq                          142
# Name: q18_clients_software_development, dtype: object
#
#
# q18_clients_training
# ======
# count     260
# unique      2
# top        No
# freq      216
# Name: q18_clients_training, dtype: object
#
#
# q18_clients_health
# ======
# count     260
# unique      2
# top        No
# freq      214
# Name: q18_clients_health, dtype: object
#
#
# q18_clients_games
# ======
# count     260
# unique      2
# top        No
# freq      182
# Name: q18_clients_games, dtype: object
#
#
# q18_clients_advertising
# ======
# count     260
# unique      2
# top        No
# freq      240
# Name: q18_clients_advertising, dtype: object
#
#
# q18_clients_engineering
# ======
# count     260
# unique      2
# top        No
# freq      236
# Name: q18_clients_engineering, dtype: object
#
#
# q18_clients_data
# ======
# count     260
# unique      2
# top        No
# freq      221
# Name: q18_clients_data, dtype: object
#
#
# q18_clients_architecture
# ======
# count     260
# unique      2
# top        No
# freq      240
# Name: q18_clients_architecture, dtype: object
#
#
# q18_clients_retail
# ======
# count     260
# unique      2
# top        No
# freq      179
# Name: q18_clients_retail, dtype: object
#
#
# q18_clients_tourism
# ======
# count     260
# unique      2
# top        No
# freq      235
# Name: q18_clients_tourism, dtype: object
#
#
# q18_clients_manufacturing
# ======
# count     260
# unique      2
# top        No
# freq      217
# Name: q18_clients_manufacturing, dtype: object
#
#
# q18_clients_automotive
# ======
# count     260
# unique      2
# top        No
# freq      201
# Name: q18_clients_automotive, dtype: object
#
#
# q18_clients_defense
# ======
# count     260
# unique      2
# top        No
# freq      219
# Name: q18_clients_defense, dtype: object
#
#
# q18_clients_hardware
# ======
# count     260
# unique      2
# top        No
# freq      148
# Name: q18_clients_hardware, dtype: object
#
#
# q18_clients_journalism_charities
# ======
# count     260
# unique      2
# top        No
# freq      216
# Name: q18_clients_journalism_charities, dtype: object
#
#
# q18_clients_energy
# ======
# count     260
# unique      2
# top        No
# freq      214
# Name: q18_clients_energy, dtype: object
#
#
# q18_clients_telecommunications
# ======
# count     260
# unique      2
# top        No
# freq      219
# Name: q18_clients_telecommunications, dtype: object
#
#
# q18_clients_finance
# ======
# count     260
# unique      2
# top        No
# freq      165
# Name: q18_clients_finance, dtype: object
#
#
# q18_clients_electronics
# ======
# count     260
# unique      2
# top        No
# freq      230
# Name: q18_clients_electronics, dtype: object
#
#
# q18_clients_other
# ======
# count     260
# unique      2
# top        No
# freq      221
# Name: q18_clients_other, dtype: object
#
#
# q19_turnover
# ======
# count                           260
# unique                           10
# top       Between Â£100k and Â£500k
# freq                             48
# Name: q19_turnover, dtype: object
#
#
# q20_growth
# ======
# count                               260
# unique                                3
# top       Higher than twelve months ago
# freq                                148
# Name: q20_growth, dtype: object
#
#
# q21_immersive_turnover
# ======
# count       248
# unique        7
# top       0-10%
# freq         67
# Name: q21_immersive_turnover, dtype: object
#
#
# q25_spend_vr
# ======
# count                        148
# unique                         9
# top       Between Â£1k and Â£10k
# freq                          42
# Name: q25_spend_vr, dtype: object
#
#
# q25_spend_ar
# ======
# count                        126
# unique                         9
# top       Between Â£1k and Â£10k
# freq                          42
# Name: q25_spend_ar, dtype: object
#
#
# q25_spend_other_ie
# ======
# count            102
# unique             9
# top       Under Â£1k
# freq              37
# Name: q25_spend_other_ie, dtype: object
#
#
# q26_future_spend_vr
# ======
# count                                          148
# unique                                           3
# top       Expect to grow in the next twelve months
# freq                                           116
# Name: q26_future_spend_vr, dtype: object
#
#
# q26_future_spend_ar
# ======
# count                                          126
# unique                                           3
# top       Expect to grow in the next twelve months
# freq                                           102
# Name: q26_future_spend_ar, dtype: object
#
#
# q26_future_spend_other_ie
# ======
# count                                          102
# unique                                           3
# top       Expect to grow in the next twelve months
# freq                                            78
# Name: q26_future_spend_other_ie, dtype: object
#
#
# q22_business_confidence
# ======
# count                248
# unique                 4
# top       Very confident
# freq                 117
# Name: q22_business_confidence, dtype: object
#
#
# q24_case_study
# ======
# count     260
# unique      2
# top       Yes
# freq      221
# Name: q24_case_study, dtype: object
#
#
# q3_role_techdev
# ======
# count                                                   260
# unique                                                    2
# top       Technology developer, e.g. a device manufactur...
# freq                                                    176
# Name: q3_role_techdev, dtype: object
#
#
# q3_role_content
# ======
# count                                                   260
# unique                                                    2
# top       Content provider, e.g. for applications, servi...
# freq                                                    195
# Name: q3_role_content, dtype: object
#
#
# q3_role_distributor
# ======
# count     260
# unique      2
# top        No
# freq      219
# Name: q3_role_distributor, dtype: object
#
#
# q3_role_service
# ======
# count     260
# unique      2
# top        No
# freq      142
# Name: q3_role_service, dtype: object
#
#
# q3_role_user
# ======
# count                              260
# unique                               2
# top       User of immersive technology
# freq                               151
# Name: q3_role_user, dtype: object
#
#
# q3_role_buyer
# ======
# count     260
# unique      2
# top        No
# freq      152
# Name: q3_role_buyer, dtype: object
#
#
# q3_role_network
# ======
# count     260
# unique      2
# top        No
# freq      236
# Name: q3_role_network, dtype: object
#
#
# q3_role_finance
# ======
# count     260
# unique      2
# top        No
# freq      243
# Name: q3_role_finance, dtype: object
#
#
# q3_role_other
# ======
# count     260
# unique      2
# top        No
# freq      223
# Name: q3_role_other, dtype: object
#
#
# Unnamed: 0
# ======
#         Unnamed: 0    Unnamed: 0
# count          252  2.480000e+02
# unique         252           NaN
# top         N1 7GU           NaN
# freq             1           NaN
# mean           NaN  3.383219e+06
# std            NaN  2.196914e+04
# min            NaN  3.347648e+06
# 25%            NaN  3.372584e+06
# 50%            NaN  3.386589e+06
# 75%            NaN  3.400416e+06
# max            NaN  3.464635e+06
#
#
# administrative_area_level_1
# ======
# count         252
# unique         11
# top       England
# freq          217
# Name: administrative_area_level_1, dtype: object
#
#
# address
# ======
# count                                     252
# unique                                    250
# top       Parliament St, Liverpool L8 5RN, UK
# freq                                        2
# Name: address, dtype: object
#
#
# lng
# ======
# count    252.000000
# mean      -0.617560
# std        8.143265
# min       -6.686936
# 25%       -2.582000
# 50%       -0.475341
# 75%       -0.123701
# max      100.872573
# Name: lng, dtype: float64
#
#
# lat
# ======
# count    252.000000
# mean      51.961499
# std        3.331218
# min       19.080234
# 25%       51.469550
# 50%       51.536945
# 75%       53.394458
# max       57.142550
# Name: lat, dtype: float64
#
#
# country
# ======
# count                252
# unique                 5
# top       United Kingdom
# freq                 245
# Name: country, dtype: object
#
#
# postal_town
# ======
# count        245
# unique        96
# top       London
# freq          80
# Name: postal_town, dtype: object
#
#
# administrative_area_level_2
# ======
# count                246
# unique                62
# top       Greater London
# freq                  85
# Name: administrative_area_level_2, dtype: object
#
#
# route
# ======
# count             170
# unique            163
# top       High Street
# freq                3
# Name: route, dtype: object
#
#
# Unnamed: 0
# ======
#         Unnamed: 0    Unnamed: 0
# count          252  2.480000e+02
# unique         252           NaN
# top         N1 7GU           NaN
# freq             1           NaN
# mean           NaN  3.383219e+06
# std            NaN  2.196914e+04
# min            NaN  3.347648e+06
# 25%            NaN  3.372584e+06
# 50%            NaN  3.386589e+06
# 75%            NaN  3.400416e+06
# max            NaN  3.464635e+06
#
#
# snippet
# ======
# count                                             43
# unique                                            43
# top       IDENTITY GRAPHIC DESIGN AND DIGITAL MEDIA
# freq                                               1
# Name: snippet, dtype: object
#
#
# title
# ======
# count                        248
# unique                       246
# top       THE OLD MARKET LIMITED
# freq                           2
# Name: title, dtype: object
#
#
# company_status
# ======
# count        247
# unique         4
# top       active
# freq         237
# Name: company_status, dtype: object
#
#
# address_snippet
# ======
# count                                                   241
# unique                                                  237
# top       Europa House, Goldstone Villas, Hove, East Sus...
# freq                                                      3
# Name: address_snippet, dtype: object
#
#
# company_type
# ======
# count     248
# unique      8
# top       ltd
# freq      214
# Name: company_type, dtype: object
#
#
# postal_code
# ======
# count         241
# unique        237
# top       BN3 3RQ
# freq            3
# Name: postal_code, dtype: object
#
#
# region
# ======
# count         95
# unique        43
# top       Surrey
# freq          12
# Name: region, dtype: object
#
#
# premises
# ======
# count     241
# unique    203
# top        1
# freq        4
# Name: premises, dtype: object
#
#
# locality
# ======
# count        236
# unique       121
# top       London
# freq          63
# Name: locality, dtype: object
#
#
# description
# ======
# count                                             248
# unique                                            246
# top       10534368 - Incorporated on 21 December 2016
# freq                                                2
# Name: description, dtype: object
#
#
# address_line_1
# ======
# count                  239
# unique                 235
# top       Goldstone Villas
# freq                     3
# Name: address_line_1, dtype: object
#
#
# date_of_creation
# ======
# count            241
# unique           232
# top       2011-04-07
# freq               3
# Name: date_of_creation, dtype: object
#
#
# company_number
# ======
# count          248
# unique         246
# top       10534368
# freq             2
# Name: company_number, dtype: object
#
#
# pcds
# ======
# count         210
# unique        205
# top       BN1 4GH
# freq            4
# Name: pcds, dtype: object
#
#
# ttwa
# ======
# count           210
# unique           62
# top       E30000234
# freq             65
# Name: ttwa, dtype: object
#
#
# ttwa_name
# ======
# count        210
# unique        62
# top       London
# freq          65
# Name: ttwa_name, dtype: object

# %% [markdown]
# ## EDA preliminary analysis

# %% [markdown]
# ### Where are they?

# %%
# Functions

def create_lq_df(df):
    '''
    Takes a df with cells = activity in col in row and returns a df with cells = lq
    
    '''
    
    area_activity = df.sum(axis=0)
    area_shares = area_activity/area_activity.sum()
    
    lqs = df.apply(lambda x: (x/x.sum())/area_shares, axis=1)
    return(lqs)

def save_fig(name):
    plt.tight_layout()
    plt.savefig(fig_path+'/{name}.pdf'.format(name=name),bbox_inches='tight')

# %%
idbr.head()
# Out:
#                 ttwa_name  ttwa_code       year  Advertising and marketing  \
# 0                Aberdeen  S22000047  2011_2014                       58.0
# 1                Aberdeen  S22000047  2015_2016                       65.0
# 2             Aberystwyth  W22000021  2011_2014                        9.0
# 3             Aberystwyth  W22000021  2015_2016                        NaN
# 4  Alness and Invergordon  S22000048  2011_2014                        3.0
#
#    All creative industries  Architecture  \
# 0                   1155.0         191.0
# 1                   1247.5         182.5
# 2                    117.0          11.0
# 3                    120.0           NaN
# 4                     29.0           8.0
#
#    Design: product, graphic and fashion design  \
# 0                                        103.0
# 1                                        110.0
# 2                                          6.0
# 3                                          NaN
# 4                                          NaN
#
#    Film, TV, video, radio and photography  IT, software and computer services  \
# 0                                    84.0                               519.0
# 1                                    82.5                               605.0
# 2                                    15.0                                36.0
# 3                                     NaN                                 NaN
# 4                                     3.0                                 9.0
#
#    Music, performing and visual arts  Publishing  not_creative    region  \
# 0                              154.0        47.0  26250.000000  Scotland
# 1                              155.0        47.5  30140.000000  Scotland
# 2                               21.0        20.0   3078.947368     Wales
# 3                                NaN         NaN   3075.000000     Wales
# 4                                4.0         NaN    966.666667  Scotland
#
#    is_cluster
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
#Load GlassAI datasets where we have locations (and excluding Jersey Islands)
glass_ai_locations = glass_ai_geo.dropna(axis=0,
                                         subset=['postcode_top']).loc[glass_ai_geo.lat<95,:].reset_index(drop=False)

# %%
sectors = list(glass_ai_locations.Sector.value_counts()[:4].index)+['Other']

accent_colors = plt.cm.get_cmap('Pastel1').colors[:5]

color_lookup = {x:y for x,y in zip(sectors,accent_colors)}

glass_ai_locations['sector_to_map'] = [x if x in sectors[:4] else 'Other' for x in glass_ai_locations['Sector']]

# %%
sectors
# Out:
# ['Technology',
#  'Professional Services',
#  'Non Profit and Education',
#  'Media and Arts',
#  'Other']

# %%
import geopandas as gp

uk_map = gp.read_file(ext_data+'/StatPlanet_UK/map/map.shp')


fig, ax = plt.subplots(ncols=5,figsize=(20,8))

for number in np.arange(0,5):
    
    uk_map.plot(ax=ax[number],color='darkslategrey',edgecolor='black')

    sector_orgs = glass_ai_locations.loc[glass_ai_locations.sector_to_map==sectors[number],:]
    
    ax[number].scatter(sector_orgs['long'],sector_orgs['lat'],color=color_lookup[sectors[number]],alpha=0.7,
                       marker='s',
                       s=25,
                       #edgecolor='white',
                       #linewidth=1
                      )
    ax[number].set_title(sectors[number],fontsize=14)
    
    ax[number].xaxis.set_visible(False)
    ax[number].yaxis.set_visible(False)
               

plt.subplots_adjust(wspace=0.05)

fig.suptitle('GlassAI company distribution',y=1.05,fontsize=18)

plt.tight_layout()

plt.savefig(fig_path+'/maps.pdf',bbox_inches='tight')

# %%
#IDBR
idbr = pd.read_csv(ext_data+'/idbr_business_totals.csv')

glass_b_count = pd.concat([idbr.loc[(
    idbr.year=='2015_2016'),['ttwa_name','All creative industries','not_creative']].set_index('ttwa_name').sum(axis=1),
                         glass_ai_geo.ttwa_name.value_counts()],axis=1)
                         
glass_b_count.columns=['all','immersive']

glass_b_count_lq = create_lq_df(glass_b_count.fillna(0))

glass_b_count_lq.columns = ['all_lq','immersive_lq']

#Combine Business counts and LQs

glass_b_count_lq = pd.concat([glass_b_count,glass_b_count_lq],axis=1)
glass_b_count_lq['immersive_share'] = 100*np.round(glass_b_count_lq['immersive']/glass_b_count_lq['immersive'].sum(),2)


glass_top_20_ttwas = glass_b_count_lq.sort_values('immersive',ascending=False)[:20]

top_20 = glass_top_20_ttwas.index

# %%
fig,ax = plt.subplots(nrows=2,figsize=(12,6),sharex=True)


glass_top_20_ttwas['immersive'].plot.bar(ax=ax[0],title='Total businesses (n)',color='orange')
glass_top_20_ttwas['immersive_lq'].plot.bar(ax=ax[1],title='Relative specialisation (LQ)',color='orange')

ax[1].hlines(y=1,xmin=0,xmax=20,color='blue',linestyle='--')
ax[0].set_ylim((0,600))

for num,x in enumerate(glass_top_20_ttwas.index):
    ax[0].annotate(s=str(int(glass_top_20_ttwas.loc[x,['immersive_share']]))+'%',xy=(num-0.3,
                                                                       glass_top_20_ttwas.loc[x,['immersive']]+5))

fig.suptitle('Top 20 locations',fontsize=14,y=1.02)
    
save_fig('places')

# %%
#TTWA sector shares

sector_ordered = glass_ai['Sector'].value_counts(ascending=False).index

ttwa_sector_shares = pd.crosstab(glass_ai_geo['Sector'],
                                 glass_ai_geo.ttwa_name).loc[sector_ordered,top_20].apply(lambda x: x/x.sum())

# %%
fig,ax = plt.subplots(figsize=(13,5))


ttwa_sector_shares.T.plot.bar(stacked=True,ax=ax,width=0.8,cmap='tab20_r')

ax.set_title('Local specialisms',fontsize=16)

ax.set_xlim(-1,27)
ax.legend(loc='center right')

save_fig('local_specialisms')

# %% [markdown]
# ### Dweeby coverage point
#
# Are some locations over/under represented in the survey?

# %%
glass_with_survey = pd.concat([glass_ai_geo['ttwa_name'].value_counts(),
                               survey_data['ttwa_name'].value_counts()],axis=1).fillna(0)

glass_with_survey.columns=['glass_share','survey_share']

glass_with_survey_shares = 100*glass_with_survey.apply(lambda x: x/x.sum()).sort_values(
    'survey_share',ascending=False).iloc[1:,:]

# %%
fig,ax = plt.subplots(figsize=(5,5))

glass_with_survey_shares.plot.scatter(x='glass_share',y='survey_share',ax=ax,
                                      title='Share in GlassAI vs response rate (excluding London)')

# %%
#Correlation coefficient excluding London
glass_with_survey_shares.iloc[1:,:].corr()
# Out:
#               glass_share  survey_share
# glass_share      1.000000      0.698503
# survey_share     0.698503      1.000000

# %% [markdown]
# ## Key variables

# %%
#np.sum(survey_data.ttwa_name.isna())

survey_data.ttwa_name.value_counts()[:10]
# Out:
# London                     65
# Liverpool                  13
# Brighton                   13
# Bristol                    10
# Belfast                    10
# Manchester                  7
# Guildford and Aldershot     7
# Slough and Heathrow         5
# Edinburgh                   5
# Glasgow                     4
# Name: ttwa_name, dtype: int64

# %%
#Age
print(survey_data.q15_company_incorporation.median())
100%np.sum(survey_data.q15_company_incorporation>2011)/len(survey_data)
# Out:
# 2012.0
# 0.38461538461538464

# %%
#Employee numbers
survey_data.q16_employees.value_counts()

survey_data_sizes = pd.Series([
    '0_single worker' if x=='0' else '1_micro' if x in [
        '1-2','3-5','6-10'] else '2_small' if x in ['11-25','26-60'] else '3_medium' if x in [
        '51-100','101-250'] else '4_big' for x in survey_data.q16_employees]).value_counts(normalize=True)

100*survey_data_sizes
# Out:
# 1_micro            56.153846
# 4_big              17.692308
# 2_small             9.615385
# 0_single worker     8.846154
# 3_medium            7.692308
# dtype: float64

# %%
#Turnover

100*survey_data.q19_turnover.value_counts(normalize=True)
# Out:
# Between Â£100k and Â£500k    18.461538
# Pre-revenue                  14.230769
# Between Â£50k and Â£100k     11.923077
# Between Â£1m and Â£5m        11.538462
# Under Â£50k                  11.153846
# Prefer not to say            11.153846
# Over Â£25m                    9.230769
# Between Â£500k and Â£1m       8.076923
# Between Â£10m and Â£25m       3.461538
# Between Â£5m and Â£10m        0.769231
# Name: q19_turnover, dtype: float64

# %% [markdown]
# ### What is their role?

# %%
role_data = survey_data.loc[:,['q3_role_' in x for x in survey_data.columns]]
role_data_bin = role_data.applymap(lambda x: 1 if x!='No' else 0)

# %%
fig,ax = plt.subplots(figsize=(8,5))

#Roles
role_data_bin.sum().sort_values(ascending=False).plot.bar(ax=ax,color='orange',title='Company roles')

# %%
#from itertools import product


role_mix_df = pd.DataFrame(columns=role_data_bin.columns,index=role_data_bin.columns)

extracted=[]

for x in role_data_bin.columns:
    for y in role_data_bin.columns:
        ct = pd.crosstab(role_data_bin[x],role_data_bin[y])
        role_mix_df.loc[x,y] = ct.iloc[1,1]/np.max([role_data_bin[x].sum(),role_data_bin[y].sum()])
        role_mix_df.loc[y,x] = ct.iloc[1,1]/np.max([role_data_bin[x].sum(),role_data_bin[y].sum()])
            
        #    extracted.append([x,y])
            
role_mix_df = role_mix_df.fillna(0)

# %%
fig,ax = plt.subplots(figsize=(10,6))

ax.imshow(role_mix_df,aspect='auto')


ax.set_xticks(np.arange(len(role_mix_df.columns)))
ax.set_xticklabels(role_mix_df.columns,rotation=90,size=12)

ax.set_yticks(np.arange(len(role_mix_df.columns)))
ax.set_yticklabels(role_mix_df.columns,size=12)

ax.set_title('Role overlap',size=18)
# Out:
# Text(0.5,1,'Role overlap')

# %%
fig,ax = plt.subplots(ncols=2,figsize=(11,5),sharey='col')

#Roles

ordered_roles = role_data_bin.sum().sort_values(ascending=False).index

role_data_bin.sum().sort_values(ascending=True).plot.barh(ax=ax[0],color='orange',title='Company roles')

#Role mix
ax[1].imshow(role_mix_df.loc[ordered_roles,ordered_roles],aspect='auto',cmap='coolwarm')


ax[1].set_xticks(np.arange(len(ordered_roles)))
ax[1].set_xticklabels(ordered_roles,rotation=90,size=12)

ax[1].set_yticks(np.arange(len(ordered_roles)))
ax[1].set_yticklabels(['' for x in ordered_roles],size=12)

ax[1].set_title('Role overlap',size=12)

plt.subplots_adjust(wspace=0.05)

fig.suptitle('Company roles in survey',fontsize=16,y=1.03)

save_fig('roles_survey')

# %%
core_roles = ['q3_role_techdev','q3_role_content','q3_role_distributor']
market_roles = ['q3_role_buyer']

is_core = [role_data_bin.loc[number,core_roles].sum()>0 for number in np.arange(0,len(role_data_bin))]
is_market =[role_data_bin.loc[number,market_roles].sum()>0 for number in np.arange(0,len(role_data_bin))]

# %%
is_only_core = [x and not y for x,y in zip(is_core,is_market)]
is_only_market = [y and not x for x,y in zip(is_core,is_market)]

# %%
#Revenue from immersive
100*survey_data[is_only_core].q21_immersive_turnover.value_counts(normalize=True)
# Out:
# 100%      28.776978
# 0-10%     23.741007
# None      11.510791
# 51-75%    10.071942
# 11-25%     9.352518
# 76-99%     8.633094
# 26-50%     7.913669
# Name: q21_immersive_turnover, dtype: float64

# %%
fig,ax = plt.subplots(figsize=(10,6))

process_question('q18_clients')[1][is_only_core].sum().sort_values(ascending=True).plot.barh(
    ax=ax,
    color='orange',title='Client sectors (only \'core\' respondents)')

ax.set_xlabel('Total')

save_fig('clients')

# %% [markdown]
# ### What is their performance
# * Way in which IE creates value for users
# * Clients, exports, prospects

# %%
def process_question(var_name,var_type='binary'):
    '''
    This function turns a variable into counts. 
    
    '''
    if var_type=='binary':
    
        data = survey_data.loc[:,[var_name in x for x in survey_data.columns]]
        data_bin = data.applymap(lambda x: 1 if x !='No' else 0)
        
    elif var_type=='likert':
        data = survey_data.loc[:,[var_name in x for x in survey_data.columns]]
        data_bin = data.applymap(lambda x: 1 if x=='Very important' else 0)
        
    
    return([data,data_bin])

# %%
benefits_bin = process_question('q7_value')[1]

fig,ax = plt.subplots(ncols=2,figsize=(12,5),sharey=True)

#Benefits obtained
benefits_bin[is_only_core].sum().sort_values(ascending=False).plot.bar(ax=ax[0],color='orange',
                                                                       title='Benefits: \'Core companies \'')
benefits_bin[is_market].sum().sort_values(ascending=False).plot.bar(ax=ax[1],color='orange',
                                                                    title='Benefits: \'Client companies\'')

plt.tight_layout()

fig.suptitle('Benefits by company type',size=16,y=1.02)

save_fig('benefits_type')

# %%
for x in survey_data.columns:
    print(x)
# Out:
# name
# survey_postcode
# id
# name
# q3_market_role_vr_techdev
# q3_market_role_ar_techdev
# q3_market_role_other_ie_techdev
# q3_market_role_vr_content
# q3_market_role_ar_content
# q3_market_role_other_ie_content
# q3_market_role_vr_distributor
# q3_market_role_ar_distributor
# q3_market_role_other_ie_distributor
# q3_market_role_vr_services
# q3_market_role_ar_services
# q3_market_role_other_ie_services
# q3_market_role_vr_user
# q3_market_role_ar_user
# q3_market_role_other_ie_user
# q3_market_role_vr_buyer
# q3_market_role_ar_buyer
# q3_market_role_other_ie_buyer
# q3_market_role_vr_network
# q3_market_role_ar_network
# q3_market_role_other_ie_network
# q3_market_role_vr_finance
# q3_market_role_ar_finance
# q3_market_role_other_ie_finance
# q3_market_role_vr_other
# q3_market_role_ar_other
# q3_market_role_other_ie_other
# q3_market_role_vr_none
# q3_market_role_ar_none
# q3_market_role_other_ie_none
# q4_product_hardware
# q4_product_software
# q4_product_application
# q4_product_content
# q4_product_service
# q4_product_other
# q5_immersive_use
# q7_value_new_products
# q7_value_new_markets
# q7_value_new_collaborators
# q7_value_wider_clients
# q7_value_better_perception
# q7_value_new_marketing
# q7_value_fast_prototyping
# q7_value_change_culture
# q7_value_better_efficiency
# q7_value_better_organisation
# q7_value_other
# q8_immersive_export
# q9_export_market
# q10_local_factors_ecosystem
# q10_local_factors_skills_supply
# q10_local_factors_good_place
# q10_local_factors_research_base
# q10_local_factors_public_finance
# q10_local_factors_private_finance
# q10_local_factors_local_customers
# q10_local_factors_infrastructure
# q10_local_factors_technology_expertise
# q12_finance_friends_family
# q12_finance_crowdfunding
# q12_finance_equity
# q12_finance_banks
# q12_finance_incubator_accelerator
# q12_finance_coworking_space
# q12_finance_local_grant
# q12_finance_national_grant
# q12_finance_tax_incentives
# q13_other_support_mentoring
# q13_other_support_training_tech
# q13_other_support_training_marketing
# q13_other_support_placements
# q13_other_support_university_support
# q14_barriers_finance
# q14_barriers_economic_climate
# q14_barriers_skills_shortages
# q14_barriers_skills_shortages_education
# q14_barriers_access_university_knowledge
# q14_barriers_technical_infrastructure
# q14_barriers_market_knowledge
# q14_barriers_lack_advice
# q14_barriers_office_space
# q14_barriers_government_policy
# q14_barriers_transport
# q14_barriers_technology_understanding
# q14_barriers_device_penetratiom
# q14_barriers_business_model
# q14_barriers_lack_standards
# q14_barriers_fragmented_tech_ecosystem
# q14_barriers_poor_applications
# q14_barriers_lack_time_resources
# q14_barriers_oher
# q15_company_incorporation
# q16_employees
# q17_freelancers
# q18_clients_media
# q18_clients_education
# q18_clients_software_development
# q18_clients_training
# q18_clients_health
# q18_clients_games
# q18_clients_advertising
# q18_clients_engineering
# q18_clients_data
# q18_clients_architecture
# q18_clients_retail
# q18_clients_tourism
# q18_clients_manufacturing
# q18_clients_automotive
# q18_clients_defense
# q18_clients_hardware
# q18_clients_journalism_charities
# q18_clients_energy
# q18_clients_telecommunications
# q18_clients_finance
# q18_clients_electronics
# q18_clients_other
# q19_turnover
# q20_growth
# q21_immersive_turnover
# q25_spend_vr
# q25_spend_ar
# q25_spend_other_ie
# q26_future_spend_vr
# q26_future_spend_ar
# q26_future_spend_other_ie
# q22_business_confidence
# q24_case_study
# q3_role_techdev
# q3_role_content
# q3_role_distributor
# q3_role_service
# q3_role_user
# q3_role_buyer
# q3_role_network
# q3_role_finance
# q3_role_other
# Unnamed: 0
# administrative_area_level_1
# address
# lng
# lat
# country
# postal_town
# administrative_area_level_2
# route
# Unnamed: 0
# snippet
# title
# company_status
# address_snippet
# company_type
# postal_code
# region
# premises
# locality
# description
# address_line_1
# date_of_creation
# company_number
# pcds
# ttwa
# ttwa_name

# %%
fig,ax = plt.subplots(nrows=3,figsize=(12,6),sharex=True)


survey_data[
    'q20_growth'].value_counts(normalize=True).plot.barh(ax=ax[0],color='orange',title='Turnover vs 12 months ago')
survey_data[
    'q22_business_confidence'].value_counts(normalize=True).plot.barh(ax=ax[1],color='orange',title='Business confidence')
survey_data.loc[
    is_market,'q26_future_spend_vr'].value_counts(normalize=True).plot.barh(ax=ax[2],color='orange',
                                                             title='VR spend plans \n (only companies in user/buyer role)')

fig.suptitle('Recent and future growth',fontsize=14,y=1.02)

save_fig('prospects')

# %%
fig,ax = plt.subplots(nrows=2,sharex=True,figsize=(10,5))

survey_data.loc[:,'q8_immersive_export'].value_counts(normalize=True).plot.barh(ax=ax[0],color='orange',
                                                                                      title='Exports?')
survey_data.loc[:,'q9_export_market'].value_counts(normalize=True).sort_values(ascending=True).plot.barh(ax=ax[1],color='orange',
                                                                                   title='Export market')

fig.suptitle('Export Activities',fontsize=14,y=1.03)


save_fig('exports')

# %% [markdown]
# ### What are the local advantages in different locations ?
#
# * Includes access to finance

# %%
#Get sorted indices
local_factors_sorted = pd.concat([survey_data.reset_index(drop=True)['ttwa_name'],
                             process_question(
                                 'q10_local_factors',var_type='likert')[1].reset_index(drop=True)],axis=1).groupby(
    'ttwa_name').sum().mean(axis=0).sort_values(ascending=False).index

# %%
#Place ecosystem
place_ecosystem = pd.concat([survey_data.reset_index(drop=True)['ttwa_name'],
                             process_question(
                                 'q10_local_factors',var_type='likert')[1].reset_index(drop=True)],axis=1).groupby(
    'ttwa_name').sum().apply(lambda x:x/x.sum(),axis=1).loc[top_20[:10],local_factors_sorted]

fig,ax = plt.subplots(figsize=(10,7))


plt.imshow(place_ecosystem.rank(axis=0)[local_factors_sorted],cmap='coolwarm',aspect='auto')

ax.set_yticks(np.arange(len(place_ecosystem)))
ax.set_yticklabels(place_ecosystem.index,size=12)

ax.set_xticks(np.arange(len(place_ecosystem.columns)))
ax.set_xticklabels(place_ecosystem.columns,rotation=45,ha='right',size=12)

ax.set_title('Local advantages by location',size=18)

save_fig('local_advantages')

# %%
#Barrier questions
q14_questions = [x for x in survey_data.columns if 'q14' in x]

ecosystem_questions = [0,1,2,3,4,5,6,7,8]

selected_questions = [x for num,x in enumerate(q14_questions) if num in ecosystem_questions]

not_local_questions = [x for num,x in enumerate(q14_questions) if num not in ecosystem_questions]

# %%
#Get sorted indices
local_barriers_sorted = pd.concat([survey_data.reset_index(drop=True)['ttwa_name'],
                             process_question(
                                 'q14_barriers',var_type='binary')[1].reset_index(drop=True)],axis=1).groupby(
    'ttwa_name').sum()[selected_questions].mean(axis=0).sort_values(ascending=False).index

#Place ecosystem
place_barriers = pd.concat([survey_data.reset_index(drop=True)['ttwa_name'],
                             process_question(
                                 'q14_barriers',var_type='binary')[1].reset_index(drop=True)],axis=1).groupby(
    'ttwa_name').sum().apply(lambda x:x/x.sum(),axis=1)[selected_questions].loc[top_20[:10],:]

# %%
fig,ax = plt.subplots(figsize=(12,7),ncols=2,sharey=True)


ax[0].imshow(place_ecosystem.rank(axis=0)[local_factors_sorted],cmap='coolwarm',aspect='auto')
ax[1].imshow(place_barriers.rank(axis=0)[local_barriers_sorted],cmap='coolwarm',aspect='auto')

#Axes and title for first heatmap
ax[0].set_yticks(np.arange(len(place_barriers)))
ax[0].set_yticklabels(place_barriers.index,size=12)

ax[0].set_xticks(np.arange(len(place_ecosystem.columns)))
ax[0].set_xticklabels(place_ecosystem.columns,rotation=45,ha='right',size=12)
ax[0].set_title('Local advantages')

#Axes and barriers for second heatmap

ax[1].set_xticks(np.arange(len(place_barriers.columns)))
ax[1].set_xticklabels(local_barriers_sorted,rotation=45,ha='right',size=12)
ax[1].set_title('Local barriers')

fig.suptitle('Local ecosystem snapshot',
             y=1.02,x=0.56,
             fontsize=14)
plt.subplots_adjust(wspace=0.1)

plt.tight_layout()

plt.savefig(fig_path+'/ecosystems_snapshot.pdf',bbox_inches='tight')

# %%
#Identify general barriers (all companies)

not_only_core = [not x for x in is_only_core]

general_barriers_count = process_question(
    'q14_barriers',var_type='binary')[1].sum()[not_local_questions]

#general_barriers_sorted = general_barriers_count.sort_values(ascending=False)/np.sum(general_barriers_count)

#Identify general barriers (core companies)
general_barriers_core = process_question(
    'q14_barriers',var_type='binary')[1][is_only_core].sum()[not_local_questions]

general_barriers = pd.concat([general_barriers_count,general_barriers_core],axis=1)

general_barriers.columns=['All companies','Only core']

general_barriers['share_all_companies'] = general_barriers['All companies']/260
general_barriers['share_all_core'] = general_barriers['Only core']/np.sum(not_only_core)

# %%
fig,ax = plt.subplots(figsize=(12,7))

general_barriers[['share_all_companies','share_all_core']].sort_values(
    'share_all_companies').plot.barh(ax=ax,title='Barriers faced by company')

save_fig('general_barriers')

# %%
6500*20/100
# Out:
# 1300.0

# %%
(6500+1300)/2
# Out:
# 3900.0
